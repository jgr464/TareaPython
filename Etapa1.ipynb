# %%
import truststore
truststore.inject_into_ssl()
from bicimad.bicimad import BiciMad
bici = BiciMad(7, 21)
print(bici.data.columns.tolist())
print(len(bici.data.columns))
# Out:
# ['idBike', 'fleet', 'trip_minutes', 'geolocation_unlock', 'address_unlock', 'locktype', 'unlocktype', 'geolocation_lock', 'address_lock', 'lock_date', 'station_unlock', 'unlock_station_name', 'station_lock', 'lock_station_name']
# 14

# %%
df=bici.data
df.head()
# Out:
#                      idBike  fleet  trip_minutes  \
# unlock_date
# NaT                     NaN    NaN           NaN
# 2021-07-01 00:00:03   284.0    1.0          5.05
# NaT                     NaN    NaN           NaN
# 2021-07-01 00:00:09  7074.0    1.0          7.90
# NaT                     NaN    NaN           NaN
#
#                                                     geolocation_unlock  \
# unlock_date
# NaT                                                                NaN
# 2021-07-01 00:00:03  {'type': 'Point', 'coordinates': [-3.6991147, ...
# NaT                                                                NaN
# 2021-07-01 00:00:09  {'type': 'Point', 'coordinates': [-3.6954983, ...
# NaT                                                                NaN
#
#                     address_unlock locktype unlocktype  \
# unlock_date
# NaT                            NaN      NaN        NaN
# 2021-07-01 00:00:03            NaN  STATION    STATION
# NaT                            NaN      NaN        NaN
# 2021-07-01 00:00:09            NaN  STATION    STATION
# NaT                            NaN      NaN        NaN
#
#                                                       geolocation_lock  \
# unlock_date
# NaT                                                                NaN
# 2021-07-01 00:00:03  {'type': 'Point', 'coordinates': [-3.6933463, ...
# NaT                                                                NaN
# 2021-07-01 00:00:09  {'type': 'Point', 'coordinates': [-3.6766111, ...
# NaT                                                                NaN
#
#                     address_lock           lock_date  station_unlock  \
# unlock_date
# NaT                          NaN                 NaT             NaN
# 2021-07-01 00:00:03          NaN 2021-07-01 00:05:06            45.0
# NaT                          NaN                 NaT             NaN
# 2021-07-01 00:00:09          NaN 2021-07-01 00:08:03            20.0
# NaT                          NaN                 NaT             NaN
#
#                     unlock_station_name  station_lock  lock_station_name
# unlock_date
# NaT                                 NaN           NaN                NaN
# 2021-07-01 00:00:03        Antón Martín          54.0  Museo Reina Sofía
# NaT                                 NaN           NaN                NaN
# 2021-07-01 00:00:09                Prim         189.0       Retiro-Ibiza
# NaT                                 NaN           NaN                NaN
